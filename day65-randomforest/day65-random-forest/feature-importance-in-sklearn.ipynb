# %%
import pandas as pd 
import seaborn as sns

# %%
df=pd.read_csv('/Users/siddharthkushwaha/Desktop/ML/day65-randomforest/day65-random-forest/train (6).csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
X = df.iloc[:,1:]
y = df.iloc[:,0]

# %%
print(X.shape)
print(X.iloc[5].shape)
print(X.iloc[5].values)
# Out:
# (891, 11)
# (11,)
# [np.int64(0) np.int64(3) 'Moran, Mr. James' 'male' np.float64(nan)
#  np.int64(0) np.int64(0) '330877' np.float64(8.4583) nan 'Q']

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/siddharthkushwaha/Desktop/ML/day65-randomforest/day65-random-forest/train (6).csv')

print("Dataset shape:", df.shape)

X = df.iloc[:, 1:]
y = df.iloc[:, 0]

print("X shape:", X.shape)
print("Number of features:", X.shape[1])
# Out:
# Dataset shape: (891, 12)
# X shape: (891, 11)
# Number of features: 11
