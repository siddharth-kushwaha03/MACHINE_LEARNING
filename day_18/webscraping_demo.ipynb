# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 0

# %%
len(soup.find_all('a' , class_='review-count'))
# Out:
# 0

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
for i in company:

  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  reviews.append(i.find('a' , class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df=pd.DataFrame({'name':name,
   'rating':rating,
   'reviews':reviews,
   'company_type':ctype,
   'Head_Quarters':hq,
   'Company_Age':how_old,
   'No_of_Employee':no_of_employee,
   })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 11
#       8   how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
#       9   no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())
# ---> 11 df=pd.DataFrame({'name':name,
#      12    'rating':rating,
#      13    'reviews':reviews,
#      14    'company_type':ctype,
#      15    'Head_Quarters':hq,
#      16    'Company_Age':how_old,
#      17    'No_of_Employee':no_of_employee,
#      18    })
#
# NameError: name 'name' is not defined
